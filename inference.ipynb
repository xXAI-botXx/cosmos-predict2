# %% [markdown]
# # Inference

# %% [markdown]
# Test

# %%
python examples/video2world.py \
  --model_size 2B \
  --dit_path "checkpoints/posttraining/video2world/1a_physgen/checkpoints/model/iter_000018000.pt" \
  --prompt "Make a sound_reflection propagation with the sound source in the center of the image in one step." \
  --input_path "datasets/physgen_test_raw/osm/input_physgen_0.png" \
  --save_path output/test.mp4

# %%
docker run --gpus '"device=0"' --runtime=nvidia -d \
--shm-size=8g \
-v ~/src/cosmos-predict2:/workspace \
-v ~/src/cosmos-predict2/datasets:/workspace/datasets \
-v /ssd0/tippolit/checkpoints/checkpoints:/workspace/checkpoints \
--name cosmos-inference-run \
cosmos-predict2-local \
bash -c "cd /workspace && \
EXP=predict2_video2world_training_1a_physgen && \
nohup python examples/video2world.py --model_size 2B --dit_path "checkpoints/posttraining/video2world/1a_physgen/checkpoints/model/iter_000018000.pt" --prompt "Make a sound_reflection propagation with the sound source in the center of the image in one step." --input_path "datasets/physgen_test_raw/osm/input_physgen_0.png" --save_path output/test.mp4 > inference.log 2>&1 & tail -f inference.log"

# %%
docker run --gpus '"device=0"' --runtime=nvidia \
--shm-size=8g -it --rm \
-v ~/src/cosmos-predict2:/workspace \
-v ~/src/cosmos-predict2/datasets:/workspace/datasets \
-v /ssd0/tippolit/checkpoints/checkpoints:/workspace/checkpoints \
--name cosmos-inference-run \
cosmos-predict2-local
